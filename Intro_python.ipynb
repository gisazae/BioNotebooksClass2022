# %% [markdown]
# # Intro Python

# %% [markdown]
# ### Hola, Bienvenido al curso y la sección práctica introductoria a python.
# •	La necesidad de usar Python para bioinformática surge porque muchas de las herramientas disponibles, en ocasiones no abarcan gran cantidad de datos y no brindan la posibilidad al usuario de interactuar y manejar los datos de acuerdo a la investigación que estén realizando.
# •	Python es un lenguaje:
# o	Multiplataforma.
# o	Potente.
# o	Libre
# o	Versátil.
# o	Fácil.
# o	Está en constante actualización.
#
# * la ventaja de usar python recae en lo siguiente:
#     * Es un lenguaje multiplataforma
#     * Capacidad alta de procesamiento.
#     * De libre acceso.
#     * Versátil.
#     * Sintaxis adaptable y de fácil comprensión y uso.
#     * Está en constante actualización

# %% [markdown]
# ## Uso de notebooks de Jupyter
# Los notebooks tienen dos tipos de celdas, de código y de texto. **La celda que estás leyendo** es una celda de texto escrita con Markdown, un lenguaje de marcado parecido al que utiliza wikipedia para sus páginas o al HTML.
#
# Las celdas de código son ejecutables, es decir, se pueden correr individualmente (con **ctrl+enter / shift + enter** o
# desde el menu **Cell -> Run Cells**)
#
# **SE RECOMIENDA LEER EN CADA CELDA LOS COMENTARIOS ALLÍ CONTENIDOS**

# %%
#Este es un comentario porque empieza con #
# Esta es una celda de código
# Se ejecuta con ctrl+enter --- pruebalo
 
#Para escribir un texto o cadena de caracteres, basta con escribir este entre comillas dobles "" o simples ''
"hello world"
# Out:
# 'hello world'

# %%
#Para este caso la función print nos permite mostrar por la celda de resultados un contenido  determinado al usuario.
print("hello world") #impre la frase entre comillas dobles
print(4) #imprime un número
print(type("hello world")) # type nos permite idenficar el tipo de dato al que pertenece una variable, para este caso la frase ""
# Out:
# hello world
# 4
# <class 'str'>

# %%
#El operador + nos permite concatenar datos de un mismo tipo, en este caso dos STRIGNS

"bye" + "world"
# Out:
# 'byeworld'

# %% [markdown]
# # Variables
#
# Las variables en Python no necesitan ser declaradas, simplemente se definen al ser uilizadas por primera vez. Además, su valor puede ser modificado (reasignado) durante las construcción del programa, esto con fine prácticos (aunque no es recomendable)

# %%
t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %%
l = [9,8,7]
l.append([1,2,3])
l.extend([5,4,3])
l
# Out:
# [9, 8, 7, [1, 2, 3], 5, 4, 3]

# %%
#El nombre de la variable puede ser cualquiera. 
# no es valido empezar los nombres de las variables por numero ej 2variable = es valido poner _2variable
#Una variable toma una valor por la asignación que hacemos con el simbolo = 
a=5
print(a) 
cadena="hola"
print(cadena)
x,y= 16/11, "mi fecha"
#print (x,y)

#convenciones básicas de escribir o definir variables, las dos primeras son las más comunes. 
book_name = "Fire and Blood" #snake case
bookName = "Fire and Ice" #Camel Case
BookName = "El pais de la canela" #Pascal Case
# Out:
# 5
# hola

# %% [markdown]
# <font color='red'>NOTA: </font> <font color='blue'>Para cada una de las siguientes celdas de código, en caso de querer ejecutar una linea, basta con eliminar el # para que la linea funcione; ejecuta linea a linea y luego vuelve a comentar (incluir #), esto garantiza una funcion optima del entorno de ejecución y que la celda de ejecución conserve su función</font>

# %% [markdown]
# # Strings
#
# las cadenas o strings son un tipo de dato compuestos por secuencias de caracteres que representan texto. Estas cadenas de texto son e tipo str y se delimitan mediante el uso de comillas simples o dobles.

# %%
#almacenamos dentro de una variable un string
myStr= "hello world"
myStr2= "HELLO"
otra= "beauty world"
#print(dir(myStr)) #obtenemos propiedades y métodos, que nos indican como manipular los datos
#print(myStr.upper())
# print(myStr.lower())
print(myStr2.swapcase())
# print(myStr.replace('hello','bye').upper()) #Métodos encadenados, después de tener el reemplazo de hello por bye, convertimos
# #a mayusculas 
# print(myStr.count('l')) # es útil para contar el número de caracteres que hay en una frase.
# print(myStr.startswith('hello')) # quiero saber si el texto que he escrito empieza por alguna palabra, arroja true o false
# print(myStr.endswith('hello'))# quiero saber si el texto que he escrito termina por alguna palabra, arroja true o false
# print(myStr.split()) #separa a partir de un carácter en blanco por defecto por defecto, puede separar a partir de caracteres
# #de interes ejemplo: split(',')
# print(len(myStr))
# print(myStr.index('e'))
# print(myStr.isnumeric())
# print(myStr.isalpha())
#print(myStr[4])
#print(myStr2)
print("Mi saludo es: " + myStr + ' ' + otra)
# Out:
# hello
# Mi saludo es: hello world beauty world

# %% [markdown]
# # Números
# Python tiene soporte para números enteros y de punto flotante (decimal)

# %%
type(2) #Type es una función que permite reconocer el tipo de dato que estamos trabajando, en el entorno de ejecución que tipo
#de valor se trabaja.
print(type(10.1))
print(1+1+1+1+1.2*3)
print(2**2)
print(3/2)
# Out:
# <class 'float'>
# 7.6
# 4
# 1.5

# %%
#ENTEROS
x = 3 

print("- Tipo de x:")
print(type(x)) # Imprime el tipo (o `clase`) de x
print("- Valor de x:")
print(x)       # Imprimir un valor
print("- x+1:")
print(x + 1)   # Suma: imprime "4"
print("- x-1:")
print(x - 1)   # Resta; imprime "2"
print("- x*2:")
print(x * 2)   # Multiplicación; imprime "6"
print("- x^2:")
print(x ** 2)  # Exponenciación; imprime "9"
# Modificación de x
x += 1 
print("- x modificado:")
print(x)  # Imprime "4"

x *= 2
print("- x modificado:")
print(x)  # Imprime "8"

print("- Varias cosas en una línea:")
print(1,2,x,5*2) # imprime varias cosas a la vez

# %%
#FLOTANTES
y = 2.5 
print("- Tipo de y:")
print(type(y)) # Imprime el tipo de y
print("- Varios valores en punto flotante:")
print(y, y + 1, y * 2.5, y ** 2) # Imprime varios números en punto flotante
# Out:
# - Tipo de y:
# <class 'float'>
# - Varios valores en punto flotante:
# 2.5 3.5 6.25 6.25

# %%
#En el caso de pedir el dato  al usuario -- APLICA PARA QUE INGRESE CUALQUIER TIPO DE VARIABLE. 
age=input("ingrese su edad: ")

#print("tu edad es: " + age)
new_age= int(age) + 2
print ("tu nueva edad es: " , new_age)
# Out:
# ingrese su edad: 99
# tu nueva edad es:  101

# %% [markdown]
# # BOOLEANOS
# Python implementa todos los operadores usuales de la lógica booleana, usando palabras en inglés (and, or, not) en lugar de símbolos (||, &&, !, etc)
#
# También tiene los típicos operadores de comparación: <,>,>=,<=,==,!=

# %%
### Booleanos ###

v1 = True #el valor verdadero se escribe True 
v2 = False #el valor verdadero se escribe False

print("- Valores de v1 y v2:")
print(v1,v2)

print("- Tipo de v1:")
print(type(v1)) # Imprime la clase de un valor booleano ('bool')

print("- v1 and v2:")
print(v1 and v2) # y lógico; imprime False
print(v1 or v2)  # o lógico; imprime True
print(not v1)   # negación lógica, imprime False

print(3 == 5)  # Imprime False ya que son distintos
print(3 != 5)  # Imprime True ya que son distintos
print(3 < 5)  # Imprime True ya que 3 es menor que 5
# Out:
# - Valores de v1 y v2:
# True False
# - Tipo de v1:
# <class 'bool'>
# - v1 and v2:
# False
# True
# False
# False
# True
# True

# %% [markdown]
# # Listas
# Python tiene soporte para listas como un tipo predefinido del lenguaje. Para crear una lista basta con poner cosas entre [] (corchetes) y separarlas con , (comas).

# %%
print("- Lista con 4 números:")
a=[57,45,7,13] # una lista con cuatro números
print(a)

print("- Lista con 3 strings:")
b=["hola","chau","buen día"] # una lista con tres strings
print(b)

# la función `len`  da la longitud de la lista
print("- Longitud de la lista:")
n=len(a)
print(n)
# Out:
# - Lista con 4 números:
# [57, 45, 7, 13]
# - Lista con 3 strings:
# ['hola', 'chau', 'buen día']
# - Longitud de la lista:
# 4

# %%
#Para acceder a sus elementos, se utiliza el []
# Los índices comienzan en 0
print("- Elemento con índice 0 de la lista:")
print(b[0])
print("- Elemento con índice 1 de la lista:")
print(b[1])
print("- Elemento con índice 2 de la lista:")
print(b[2])
# Out:
# - Elemento con índice 0 de la lista:
# hola
# - Elemento con índice 1 de la lista:
# chau
# - Elemento con índice 2 de la lista:
# buen día

# %%
# para crear una lista vacía, (sin elementos), simplemente ponemos []
vacia=[]
print("Lista vacía:")
print(vacia)

# También puedes crear una sub-lista o slice especificando un rango de indices
print("- Elementos del índice 0 al 1 (2-1):")
print(a[0:2])
print("- Elementos del índice 1 al 3 (4-1):")
print(a[1:4])
#Si no hay nada antes del : se asume que es 0
print("- Elementos desde el comienzo al indice 1 (2-1) :")
print(a[:2])
#Si hay nada después del : se asume que toma  todos hasta el final
print("- Elementos desde el indice 1 hasta el final:")
print(a[1:])

#Si no hay nada ni antes ni después es como tomar todo
print("- Todos los elementos:")
print(a[:])


#Si el fin es igual al comienzo, es un rango vacío, por ende se obtiene una lista vacía
print("- Rango vacío -> lista vacía:")
print(a[2:2])
# Out:
# Lista vacía:
# []
# - Elementos del índice 0 al 1 (2-1):
# [57, 45]
# - Elementos del índice 1 al 3 (4-1):
# [45, 7, 13]
# - Elementos desde el comienzo al indice 1 (2-1) :
# [57, 45]
# - Elementos desde el indice 1 hasta el final:
# [45, 7, 13]
# - Todos los elementos:
# [57, 45, 7, 13]
# - Rango vacío -> lista vacía:
# []

# %% [markdown]
# # TUPLAS
# permiten poder usar un tipo de datos, parecido a la listas. son tipos de datos que no se pueden modificar, **son INMUTABLES**, es un tipo de dato que se usa solamente de lectura. Se crean con paréntesis (), en lugar de corchetes [ ].

# %%
#ejemplo
x=(1,2,3)
#print(type(x))
#las podemos crear a través de la función:
#y=tuple((1,2,3))
print(dir(x)) #conocer los mpetodos que se pueden usar con una tupla.
#si quisiera crear una tupla de un solo elemeno, se debe hacer así x=(2,), es importante incluir la (,)
#de esta manera se esta reconociendo como una tupla de un solo elemento
x=(1,2,3,4,5)
print(x[4])
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# 5

# %%
#Puede crear una tupla con valores entre () separados por ,
a=(1,2,57,4)
print("- Una tupla de cuatro elementos:")
print(a)
print("- El elemento con índice 2:")
print(a[2])
print("- Los elementos entre los índices 0 y 2:")
print(a[0:2])
# Out:
# - Una tupla de cuatro elementos:
# (1, 2, 57, 4)
# - El elemento con índice 2:
# 57
# - Los elementos entre los índices 0 y 2:
# (1, 2)

# %% [markdown]
# # Sets
# es una coleccion desordenada que no tiene un indice
# los set son usados para definir una coleccion que no tiene un indice
# #### lo usamos cuando queremos tener un conjunto de datos que usaremos indiscriminadamente durante la ejecución del programa, de esta manera el orden en que salgan o ingresen del set es indiferente y podremos llegar siempre al objetivo principal de nuestro programa.

# %%
#ejemplo 
colors={'red', 'blue', 'green'}
print(type(colors))
#si quisieramos ver la existencia de un elemento dentro del set, lo veriamos como sigue a continuacion.
print('red' in colors) #nos arroja un valor booleano True | False
#por otra parte si quisiera añadir un valor al set lo hago así: 
colors.add('violet')
print(colors)
colors.remove('red')
print(colors)
# Out:
# <class 'set'>
# True
# {'blue', 'violet', 'green', 'red'}
# {'blue', 'violet', 'green'}

# %% [markdown]
# # Diccionario

# %%
#supongamos que tenemos una tienda virtual donde tenemos un carrito de compras ¿como podriamos organzar nuestros productos?
# debemos de tener algo que nos permita tener, el producto, la cantidad, el precio del mismo, etc...
cart={
    "name":"book",
    "quantity":3,
    "price":4.99
}
person={
    "first name":"Ryan",
    "Last name":"ray"
}
#ahora quiero ver que datos o que funciones puedo ejecutar en esta variable
print(dir(person))
#ejemplo si quiero obtener las llaves o encabezados. 
print(person.keys())
print(person.items())
#puedo tener dentro de una lsita varios diccionarios:
products=[
    {"name":'book',  "price": 1.99},
    {"name": 'Laptop', "price":9088}
]
print(products)
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# dict_keys(['first name', 'Last name'])
# dict_items([('first name', 'Ryan'), ('Last name', 'ray')])
# [{'name': 'book', 'price': 1.99}, {'name': 'Laptop', 'price': 9088}]

# %% [markdown]
# # Estructuras de control

# %% [markdown]
# # Condicionales

# %%
#ejemplo so queremos comparar dos numeros
x=4
y=6
if x > y : #es importante poner la tecla tab para que se ejecuten las ordenes de manera secuencial y ordenada
    print("x es mayor que y")
elif x==y:  #EL ELIF es una condicion que sirve para añadir cuantas comparaciones yo quiera, asi sucesivamente hasta llegar al else
    print("x es igual a y")
else:
    print("x es menor que Y")
# Out:
# x es menor que Y

# %%
#Ejemplo si tengo lo siguiente. dos variables declaradas como: 
name ="jhon"
lastname="carter"

if name=="jhon":  #ejemplo de condicionales anidadas
    if lastname=="carter":
        print("Tu eres el usuario jhon carter")
    else:
        print("tu no eres jhon carter")
else:
    print("tu no eres este usuario")
# Out:
# Tu eres el usuario jhon carter

# %%
#queremos probar con operadores lógicos:
if x>3 and x <=10:
    print("x es mayor que 3 t menor que 10")
if x>3 or x<=20:
    print("x es mayor que 3")
if (not(x==y)): #pregunto de manera negada para saber si una condicion se cumple o no
    print("x no es igual a y")
# Out:
# x es mayor que 3 t menor que 10
# x es mayor que 3
# x no es igual a y

# %% [markdown]
# # LOOPS
# permiten hacer una tarea tipica con listas o un grupo de datos.

# %% [markdown]
# # For
# Sintaxis for variable in lista:. En este caso, variable es la variable que va a ir cambiando, y lista es una lista de python (o un iterable que es parecido)

# %%
print("- Impresion de los elementos de la lista:")

# Imprimir los strings de mi_lista por separado
mi_lista=["img","python","numpy"]
for s in mi_lista:
    print(s)# este print va con indentación
    
#calcular la suma de los números e imprimirla
suma=0
mis_numeros=[5,8,17,12]
for numero in mis_numeros:
    suma=suma+numero
print("- La suma de los números es:")
print(suma)
# Out:
# - Impresion de los elementos de la lista:
# img
# python
# numpy
# - La suma de los números es:
# 42

# %%
foods= ['manzanas', 'pan', 'queso', 'leche', 'banano']
#por ejemplo de la lista anterior queremos conocer si existe un elemento especifico allí 
for food in foods:    #en la lista quiero cada uno de los elementos
    if food == "queso":
        print("tienes que comprar esto")
        break #da parada al bucle si se cumple determinada condición.  tambien podemos dar 'continue'
    print(food)
# Out:
# manzanas
# pan
# tienes que comprar esto

# %%
#un for de 0 a 3, para imprimir esos valores
print("Un for de 0 a 3")
for i in range(4):
    print(i)
    
#En Python los índices comienzan en 0, y por eso los rangos también.
    

#También se puede comenzar el rango en otro valor en lugar de 0
print("- Un for de 2 a 5:")
for j in range(2,6):
    print(j)
# Out:
# Un for de 0 a 3
# 0
# 1
# 2
# 3
# - Un for de 2 a 5:
# 2
# 3
# 4
# 5

# %%
#Ejercicio: Escribir un for para buscar el máximo de la lista e imprimir su _posición_
lista=[44,11,15,29,53,12,30]
posicion=0
# IMPLEMENTAR

#debe imprimir 4
print("- La posición del máximo es:")
print(posicion)
# Out:
# - La posición del máximo es:
# 0

# %% [markdown]
# # WHILE
#
# Un bucle while permite repetir la ejecución de un grupo de instrucciones mientras se cumpla una condición (es decir, mientras la condición tenga el valor True).

# %%
count = 4 

#debemos incrementar nuestra variable contador, sino lo hacemos se ejecutará de manera infinita
while count <= 10:
    print(count)
    count+=1
print("programa terminado")
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# programa terminado

# %% [markdown]
# # FUNCIONES
# podemos mejorar nuestro codigo con las funciones, pues permiten optimizar el código de manera mas eficiente.
# por ejemplo la funcion, print, dir, type, ya tienen dentro de si un proceso automatizaodo que nos sirve para usar
# a lo largo de todo nuestro código.
#
# Las funciones se definen con la palabra clave def y tienen la sintaxis def nombre_funcion(parametros):. Para devolver un valor utilizamos la palabra clave return.
# #### Todas tienen entradas y nos dan un resultado.  nos permiten encapsular código

# %%
#ejemplo , con def --> definimos nuestra función:
def hello(name):  #en este caso esta recibiendo un parametro por valor, es decir en name recibe un nombre con el que se llama
    #la funcion, ejemplo hello("NICOLAS")
    print("HELLO ", name)

hello("JOE")
# Out:
# HELLO  JOE

# %%
#si quisieramos una función para sumar dos números
def add(n1,n2):
    return n1+n2
print(add(23,456))
print(add(34,456))
# Out:
# 479
# 490

# %%
#esta funcion recibe dos números y devuelve su suma

def sumar(a,b):
    return a+b


c=sumar(2,5)
print("2+5=")
print(c)


#esta funcion recibe una lista y devuelve la suma de sus elementos
def sumar_todos(lista):
    suma=0
    for v in lista:
        suma+=v
    return suma

mi_lista=[54,12,99,15]
print("los elementos de la lista suman:")
print(sumar_todos(mi_lista))
# Out:
# 2+5=
# 7
# los elementos de la lista suman:
# 180

# %%
#Ejercicio
# Escribir una función que reciba una lista y un valor, 
#y devuelva la cantidad de veces que aparece ese valor en la lista

def ocurrencias(lista,valor):
    # IMPLEMENTAR
    return 0


l=[1,4,2,3,5,1,4,2,3,6,1,7,1,3,5,1,1,5,3,2]
v=2

print(ocurrencias(l,v))
# Out:
# 0

# %%
#ejemplo, funciones lambda, son funciones anonimas que toman cierto número de argumentos, puden ser escritas usando una sola
#Expresión.
add= lambda n1,n2: n1+n2
print(add(34,2))
# Out:
# 36

# %% [markdown]
# # Modulos.
# usamos funciones ya hechas, facilitan los procesos y permiten usar esas aplicaciones o herramientas que ya estan testeados hace mucho tiempo y por expertos.
# #### Reutilizar lo que otros han creado para facilitar nuestro código.
# ### Podemos acceder a:  https://pypi.org/ para acceder a modulos liberados por empresas, investigadores etc...
# ### un modulo puede tener varias funciones dentro de si mismo.

# %%
#own modules
#modulos descargados de iternet
#modulos de python.
#Podemos googlear: "python modules"
#ejemplo
import datetime #si quisieras ver documentación escribes en el navegador: python datetime

print(datetime.date.today())
print(datetime.timedelta(minutes=71))
# Out:
# 2022-03-24
# 1:11:00

# %%
#si quisieramos ahorrar en escritura y llamado de funciones, hacemos lo siguiente:
from datetime import timedelta, date
#así
print(date.today())
#o por otro parte:
print(timedelta(minutes=71))
# Out:
# 2022-03-24
# 1:11:00

# %% [markdown]
# # Acumulador

# %%
suma = 0;
for var in range(1,6):
	num = int(input("Dime un número:"))
	if num % 2 == 0:
		suma = suma + num
print("La suma de los números pares es ",suma)
# Out:
# Dime un número:4
# Dime un número:5
# Dime un número:8
# Dime un número:2
# Dime un número:6
# La suma de los números pares es  20

# %%
sueldos = [1540.43, 3010.11, 980, 1200.8]
total = 0
 
for sueldo in sueldos:
	total += sueldo 
 
salario_medio = total / len(sueldos)
 
print('El total de dinero ganado es de: ' + str(total))
print('El salario medio es de ', str(salario_medio))
# Out:
# El total de dinero ganado es de: 6731.34
# El salario medio es de  1682.835

# %% [markdown]
# # Contador

# %%
numeros_pares = 0
 
for i in range(0, 100):
	if i % 2 == 0:	# si el numero i es par
		numeros_pares = numeros_pares + 1
 
print('Total de números pares econtrados: ' + str(numeros_pares))

# %%
num_par=0

for i in range(0, 100):
    if i%2 ==0:
        num_par=num_par+1
print('El total de números pares encontrados es: ', num_par)
# Out:
# El total de números pares encontrados es:  50

# %% [markdown]
# ### Hasta este punto, ya has conocido las estructuras básicas en python y como usar este lenguaje de programación
#
# ### En los notebooks que preceden esta introducción veremos como todos estos objetos y estructuras se aplican directamente en BIOINFORMÁTICA
